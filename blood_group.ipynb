# %% [markdown]
# <a href="https://colab.research.google.com/github/2303A52441/AI-ML/blob/main/blood_group.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
# Data for blood groups and their counts
blood_groups = ['A', 'B', 'AB', 'O']
counts = [50, 30, 10, 60]
# Create a bar graph
plt.bar(blood_groups, counts, color='lavender')
# Add labels and title
plt.xlabel('Blood Groups')
plt.ylabel('Number of People')
plt.title('Distribution of Blood Groups')
# Show the plot
plt.show()
