# %% [markdown]
# <a href="https://colab.research.google.com/github/2303A52441/AI-ML/blob/main/aiml_plot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
x=[1,2,3,4,5,6]
y=[10,40,0,30,20,80]
y1=[40,10,50,30,20,70]
plt.plot(x,y,y1)
plt.xlabel("Year")
plt.ylabel("Growth Rate")
plt.title("Growth rate of Company")
plt.show()
