# %% [markdown]
# <a href="https://colab.research.google.com/github/2303A52441/AI-ML/blob/main/aiml_title.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
x=[1,2,3,4,5]
y=[10,30,0,40,50]
y1=[0,25,15,45,0]
z=[90,80,70,60,65]
z1=[70,80,50,85,95]
j=plt.figure()
v=j.add_subplot(111,projection='3d')
v.plot(x,y,z)
v.plot(x,y1,z1)
v.set_xlabel("year")
v.set_ylabel("growth rate")
v.set_zlabel("Investment")
v.set_title("investment of growth")
plt.show()
